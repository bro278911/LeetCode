# %%
class Solution(object):
    def flipAndInvertImage(self, A):
        num=0
        for row in A:
            #print(1)#3
            A[num].reverse()#反轉
            num+=1
        for t in range(len(A)):
            #print(1)#3
            for i in range(len(A)):
                #print(1)#3
                if A[t][i]==1:
                    A[t][i]=0
                else:
                    A[t][i]=1
                
            
        return A
